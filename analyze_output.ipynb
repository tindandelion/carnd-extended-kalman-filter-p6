# %%
import pandas as pd
import numpy as np

# %%
output = pd.read_csv('build/output.txt', sep=";",skiprows=3,header=None)

# %%
output.describe()
# Out:
#                 0           1           2           3
# count  498.000000  498.000000  498.000000  498.000000
# mean    -0.238633    4.208505   -1.320002    0.143965
# std     15.182545   12.733552    9.845454    9.561477
# min    -26.758800  -35.987900  -34.582300  -36.880200
# 25%    -13.460575   -6.045113   -4.284760   -3.678250
# 50%     -0.029386    5.047160   -2.315510    0.228198
# 75%     13.484950   14.418625    2.764140    2.532600
# max     30.212800   25.723200   40.029200   43.241700

# %%
# ?pd.read_csv

# %%
output['x_abs'] = np.abs(output[0])

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.scatter(output[0], output[1])
# Out:
# <img src="data:image/png;base64,..." width="901.8181622717996">

# %%
output['y_abs'] = np.abs(output[1])

# %%
output[output['y_abs'] < 0.6]
# Out:
#            0         1        2         3    x_abs     y_abs
# 2    1.32889  0.461870  7.28115  0.848502  1.32889  0.461870
# 3    1.69295  0.504295  7.28115  0.848502  1.69295  0.504295
# 4    1.65998  0.508222  5.52275  1.599800  1.65998  0.508222
# 5    1.93612  0.588212  5.52275  1.599800  1.93612  0.588212
# 20   6.01555  0.598186  5.09996 -0.196226  6.01555  0.598186
# 21   6.27055  0.588374  5.09996 -0.196226  6.27055  0.588374
# 270 -5.32701  0.426150 -2.14654 -5.171990  5.32701  0.426150
# 271 -5.43433  0.167550 -2.14654 -5.171990  5.43433  0.167550

# %%
seg = output.loc[260:280]

# %%
plt.scatter(seg[0], seg[1])

# %%
seg
# Out:
#            0          1        2         3    x_abs      y_abs
# 260 -4.32726   3.052440 -2.04548  -4.84866  4.32726   3.052440
# 261 -4.42954   2.810010 -2.04548  -4.84866  4.42954   2.810010
# 262 -4.51638   2.530430 -1.96925  -4.93950  4.51638   2.530430
# 263 -4.61484   2.283460 -1.96925  -4.93950  4.61484   2.283460
# 264 -4.70673   2.037810 -2.18234  -4.84646  4.70673   2.037810
# 265 -4.81585   1.795490 -2.18234  -4.84646  4.81585   1.795490
# 266 -4.95515   1.500990 -2.31551  -4.97679  4.95515   1.500990
# 267 -5.07092   1.252150 -2.31551  -4.97679  5.07092   1.252150
# 268 -5.14758   1.060390 -2.18165  -4.81326  5.14758   1.060390
# 269 -5.25666   0.819729 -2.18165  -4.81326  5.25666   0.819729
# 270 -5.32701   0.426150 -2.14654  -5.17199  5.32701   0.426150
# 271 -5.43433   0.167550 -2.14654  -5.17199  5.43433   0.167550
# 272 -4.46704 -12.705700  5.66347 -36.88020  4.46704  12.705700
# 273 -4.18386 -14.549700  5.66347 -36.88020  4.18386  14.549700
# ...
